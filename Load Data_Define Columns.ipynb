# %%
from google.colab import drive
import pandas as pd
import pickle
import re
import os
drive.mount('/content/drive/')
df_jul=pd.read_csv('/content/drive/My Drive/BOC/Result/otherMonths/CPS_202107.csv')
df_jul_columns=df_jul.columns.to_list()
headers=[]
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
data_type=[]
count=[]
count_O=0
count_float=0
count_int=0
for col in df_jul_columns:
  dtype=df_jul[col].dtype
  data_type.append(dtype)
  if dtype=="object":
    print({col})
    count_O+=1
  elif dtype=="float64":
    count_float+=1
  elif dtype=="int64":
    count_int+=1
count.extend([count_O, count_float, count_int])
print(set(data_type))
print(count)
# Out:
# {'CPSDATE'}
# {dtype('O'), dtype('float64'), dtype('int64')}
# [1, 346, 52]

# %%
for col in df_jul_columns:
  headers.append(col)
  dtype=df_jul[col].dtype
  if col=='CPSDATE':
    print(f'{col} DATE,')
  if dtype=="int64":
    max=df_jul[col].max()
    min=df_jul[col].min()
    if  min>-32768 and max<32767:
      print(f'{col} SMALLINT,')
    elif min>-2147483648 and max<2147483647:
      print(f'{col} INT,')
    else:
      print(f'{col} BIGINT,')
  if dtype=="float64":
    print(f'{col} FLOAT,')
# Out:
# CPSDATE DATE,
# ID BIGINT,
# HRHHID2 SMALLINT,
# HUFINAL SMALLINT,
# OCCURNUM SMALLINT,
# HUINTTYP SMALLINT,
# HURESPLI SMALLINT,
# HUPRSCNT SMALLINT,
# HUTYPEA SMALLINT,
# HUTYPB SMALLINT,
# HUTYPC SMALLINT,
# HUBUS SMALLINT,
# HUBUSL1 SMALLINT,
# HUBUSL2 SMALLINT,
# HUBUSL3 SMALLINT,
# HUBUSL4 SMALLINT,
# HRMIS SMALLINT,
# HRMONTH SMALLINT,
# HRYEAR4 SMALLINT,
# HRLONGLK SMALLINT,
# QSTNUM INT,
# GEREG SMALLINT,
# GESTFIPS SMALLINT,
# GEDIV SMALLINT,
# HEHOUSUT SMALLINT,
# HXHOUSUT SMALLINT,
# HEPHONEO SMALLINT,
# HXPHONEO SMALLINT,
# HETELAVL SMALLINT,
# HXTELAVL SMALLINT,
# HETELHHD SMALLINT,
# HXTELHHD SMALLINT,
# HRHTYPE SMALLINT,
# HRINTSTA SMALLINT,
# HRNUMHOU SMALLINT,
# HEFAMINC SMALLINT,
# HXFAMINC SMALLINT,
# HWHHWGT FLOAT,
# HWHHWTLN FLOAT,
# PULINENO FLOAT,
# PUCHINHH FLOAT,
# PUWK FLOAT,
# PUBUS1 FLOAT,
# PUDIS FLOAT,
# PULAY FLOAT,
# PUHROFF1 FLOAT,
# PUHROFF2 FLOAT,
# PUHROT1 FLOAT,
# PUHROT2 FLOAT,
# PUABSOT FLOAT,
# PUBUSCK1 FLOAT,
# PUBUSCK2 FLOAT,
# ...

# %%
# %%
'PEERNH1O' in test_headers
# Out:
# True

# %%
test_headers==template_headers
# Out:
# True

# %%
columnsName='''
CPSDATE DATE,
ID BIGINT,
HRHHID2 SMALLINT,
HUFINAL SMALLINT,
OCCURNUM SMALLINT,
HUINTTYP SMALLINT,
HURESPLI SMALLINT,
HUPRSCNT SMALLINT,
HUTYPEA SMALLINT,
HUTYPB SMALLINT,
HUTYPC SMALLINT,
HUBUS SMALLINT,
HUBUSL1 SMALLINT,
HUBUSL2 SMALLINT,
HUBUSL3 SMALLINT,
HUBUSL4 SMALLINT,
HRMIS SMALLINT,
HRMONTH SMALLINT,
HRYEAR4 SMALLINT,
HRLONGLK SMALLINT,
QSTNUM INT,
GEREG SMALLINT,
GESTFIPS SMALLINT,
GEDIV SMALLINT,
HEHOUSUT SMALLINT,
HXHOUSUT SMALLINT,
HEPHONEO SMALLINT,
HXPHONEO SMALLINT,
HETELAVL SMALLINT,
HXTELAVL SMALLINT,
HETELHHD SMALLINT,
HXTELHHD SMALLINT,
HRHTYPE SMALLINT,
HRINTSTA SMALLINT,
HRNUMHOU SMALLINT,
HEFAMINC SMALLINT,
HXFAMINC SMALLINT,
HWHHWGT FLOAT,
HWHHWTLN FLOAT,
PULINENO FLOAT,
PUCHINHH FLOAT,
PUWK FLOAT,
PUBUS1 FLOAT,
PUDIS FLOAT,
PULAY FLOAT,
PUHROFF1 FLOAT,
PUHROFF2 FLOAT,
PUHROT1 FLOAT,
PUHROT2 FLOAT,
PUABSOT FLOAT,
PUBUSCK1 FLOAT,
PUBUSCK2 FLOAT,
PUBUSCK3 FLOAT,
PUBUSCK4 FLOAT,
PURETOT FLOAT,
PUHRCK1 FLOAT,
PUHRCK2 FLOAT,
PUHRCK3 FLOAT,
PUHRCK4 FLOAT,
PUHRCK5 FLOAT,
PUHRCK6 FLOAT,
PUHRCK7 FLOAT,
PUHRCK12 FLOAT,
PULAYDT FLOAT,
PULAY6M FLOAT,
PULAYAVR FLOAT,
PULK FLOAT,
PULKAVR FLOAT,
PULAYCK1 FLOAT,
PULAYCK2 FLOAT,
PULAYCK3 FLOAT,
PUDWCK1 FLOAT,
PUDWCK2 FLOAT,
PUDWCK3 FLOAT,
PUDWCK4 FLOAT,
PUDWCK5 FLOAT,
PUJHCK1 FLOAT,
PUJHCK2 FLOAT,
PUJHDP1O FLOAT,
PUJHCK3 FLOAT,
PUJHCK4 FLOAT,
PUJHCK5 FLOAT,
PULKM2 FLOAT,
PULKM3 FLOAT,
PULKM4 FLOAT,
PULKM5 FLOAT,
PULKM6 FLOAT,
PULKDK1 FLOAT,
PULKDK2 FLOAT,
PULKDK3 FLOAT,
PULKDK4 FLOAT,
PULKDK5 FLOAT,
PULKDK6 FLOAT,
PULKPS1 FLOAT,
PULKPS2 FLOAT,
PULKPS3 FLOAT,
PULKPS4 FLOAT,
PULKPS5 FLOAT,
PULKPS6 FLOAT,
PUIOCK1 FLOAT,
PUIOCK2 FLOAT,
PUIOCK3 FLOAT,
PUIODP1 FLOAT,
PUIODP2 FLOAT,
PUIODP3 FLOAT,
PUIO1MFG FLOAT,
PUIO2MFG FLOAT,
PUERN2 FLOAT,
PUERNH1C FLOAT,
PUNLFCK1 FLOAT,
PUNLFCK2 FLOAT,
PUSLFPRX FLOAT,
PUDIS1 FLOAT,
PUDIS2 FLOAT,
PUBUS2OT FLOAT,
PERRP FLOAT,
PXRRP FLOAT,
PXAGE FLOAT,
PEAFNOW FLOAT,
PXAFNOW FLOAT,
PESEX FLOAT,
PXSEX FLOAT,
PEMARITL FLOAT,
PXMARITL FLOAT,
PXRACE1 FLOAT,
PEHSPNON FLOAT,
PXHSPNON FLOAT,
PEEDUCA FLOAT,
PXEDUCA FLOAT,
PEAFEVER FLOAT,
PXAFEVER FLOAT,
PEAFWHN1 FLOAT,
PXAFWHN1 FLOAT,
PEAFWHN2 FLOAT,
PEAFWHN3 FLOAT,
PEAFWHN4 FLOAT,
PESPOUSE FLOAT,
PXSPOUSE FLOAT,
PENATVTY FLOAT,
PXNATVTY FLOAT,
PEMNTVTY FLOAT,
PXMNTVTY FLOAT,
PEFNTVTY FLOAT,
PXFNTVTY FLOAT,
PXINUSYR FLOAT,
PEDIPGED FLOAT,
PXDIPGED FLOAT,
PEHGCOMP FLOAT,
PXHGCOMP FLOAT,
PECYC FLOAT,
PXCYC FLOAT,
PEPAR1 SMALLINT,
PXPAR1 FLOAT,
PEPAR2 SMALLINT,
PXPAR2 FLOAT,
PEPAR1TYP SMALLINT,
PXPAR1TYP FLOAT,
PEPAR2TYP SMALLINT,
PXPAR2TYP FLOAT,
PRDASIAN FLOAT,
PRMARSTA FLOAT,
PTDTRACE FLOAT,
PRDTHSP FLOAT,
PRPERTYP FLOAT,
PRFAMNUM FLOAT,
PRFAMTYP FLOAT,
PRFAMREL FLOAT,
PRNMCHLD FLOAT,
PRCHLD FLOAT,
PRCITFLG FLOAT,
PRCITSHP FLOAT,
PRINUYER FLOAT,
PRTAGE FLOAT,
PRTFAGE SMALLINT,
PECOHAB FLOAT,
PXCOHAB FLOAT,
PEABSPDO FLOAT,
PEABSRSN FLOAT,
PEDWAVL FLOAT,
PEDWAVR FLOAT,
PEDWLKO FLOAT,
PEDWLKWK FLOAT,
PEDWRSN FLOAT,
PEDWWK FLOAT,
PEDWWNTO FLOAT,
PEDW4WK FLOAT,
PEHRACTT FLOAT,
PEHRACT1 FLOAT,
PEHRACT2 FLOAT,
PEHRAVL FLOAT,
PEHRFTPT FLOAT,
PEHRRSN1 FLOAT,
PEHRRSN2 FLOAT,
PEHRRSN3 FLOAT,
PEHRUSLT FLOAT,
PEHRUSL1 FLOAT,
PEHRUSL2 FLOAT,
PEHRWANT FLOAT,
PEJHRSN FLOAT,
PEJHWANT FLOAT,
PEJHWKO FLOAT,
PELAYAVL FLOAT,
PELAYDUR FLOAT,
PELAYFTO FLOAT,
PELAYLK FLOAT,
PELKAVL FLOAT,
PELKDUR FLOAT,
PELKFTO FLOAT,
PELKLL1O FLOAT,
PELKLL2O FLOAT,
PELKLWO FLOAT,
PELKM1 FLOAT,
PEMJNUM FLOAT,
PEMJOT FLOAT,
PEMLR FLOAT,
PENLFACT FLOAT,
PENLFJH FLOAT,
PENLFRET FLOAT,
PERET1 FLOAT,
PXABSPDO FLOAT,
PXABSRSN FLOAT,
PXDWAVL FLOAT,
PXDWAVR FLOAT,
PXDWLKO FLOAT,
PXDWLKWK FLOAT,
PXDWRSN FLOAT,
PXDWWK FLOAT,
PXDWWNTO FLOAT,
PXDW4WK FLOAT,
PXHRACTT FLOAT,
PXHRACT1 FLOAT,
PXHRACT2 FLOAT,
PXHRAVL FLOAT,
PXHRFTPT FLOAT,
PXHRRSN1 FLOAT,
PXHRRSN2 FLOAT,
PXHRRSN3 FLOAT,
PXHRUSLT FLOAT,
PXHRUSL1 FLOAT,
PXHRUSL2 FLOAT,
PXHRWANT FLOAT,
PXJHRSN FLOAT,
PXJHWANT FLOAT,
PXJHWKO FLOAT,
PXLAYAVL FLOAT,
PXLAYDUR FLOAT,
PXLAYFTO FLOAT,
PXLAYLK FLOAT,
PXLKAVL FLOAT,
PXLKDUR FLOAT,
PXLKFTO FLOAT,
PXLKLL1O FLOAT,
PXLKLL2O FLOAT,
PXLKLWO FLOAT,
PXLKM1 FLOAT,
PXMJNUM FLOAT,
PXMJOT FLOAT,
PXMLR FLOAT,
PXNLFACT FLOAT,
PXNLFJH FLOAT,
PXNLFRET FLOAT,
PXRET1 FLOAT,
PRABSREA FLOAT,
PRCIVLF FLOAT,
PRDISC FLOAT,
PREMPHRS FLOAT,
PREMPNOT FLOAT,
PREXPLF FLOAT,
PRFTLF FLOAT,
PRHRUSL FLOAT,
PRJOBSEA FLOAT,
PRPTHRS FLOAT,
PRPTREA FLOAT,
PRUNEDUR FLOAT,
PRUNTYPE FLOAT,
PRWKSCH FLOAT,
PRWKSTAT FLOAT,
PRWNTJOB FLOAT,
PEIO1ICD FLOAT,
PEIO2ICD FLOAT,
PEIO1OCD FLOAT,
PEIO2OCD FLOAT,
PEIO1COW FLOAT,
PEIO2COW FLOAT,
PEPDEMP1 FLOAT,
PEPDEMP2 FLOAT,
PXIO1ICD FLOAT,
PXIO2ICD FLOAT,
PXIO1OCD FLOAT,
PXIO2OCD FLOAT,
PXIO1COW FLOAT,
PXIO2COW FLOAT,
PXPDEMP1 FLOAT,
PXPDEMP2 FLOAT,
PXNMEMP1 FLOAT,
PXNMEMP2 FLOAT,
PRIOELG FLOAT,
PREMP FLOAT,
PRCOW1 FLOAT,
PRCOW2 FLOAT,
PRNAGWS FLOAT,
PRNAGPWS FLOAT,
PRDTCOW1 FLOAT,
PRDTCOW2 FLOAT,
PRMJIND1 FLOAT,
PRMJIND2 FLOAT,
PRIMIND1 FLOAT,
PRIMIND2 FLOAT,
PRMJOCC1 FLOAT,
PRMJOCC2 FLOAT,
PRDTIND1 FLOAT,
PRDTIND2 FLOAT,
PRDTOCC1 FLOAT,
PRDTOCC2 FLOAT,
PRAGNA FLOAT,
PRSJMJ FLOAT,
PRCOWPG FLOAT,
PRMJOCGR FLOAT,
PEERNPER FLOAT,
PEERNHRY FLOAT,
PEERNUOT FLOAT,
PEERNWKP FLOAT,
PEERNRT FLOAT,
PEERNH2 FLOAT,
PEERNH1O FLOAT,
PEERNHRO FLOAT,
PEERN FLOAT,
PEERNLAB FLOAT,
PEERNCOV FLOAT,
PXERNPER FLOAT,
PXERNHRY FLOAT,
PXERNUOT FLOAT,
PXERNWKP FLOAT,
PXERNRT FLOAT,
PXERNH2 FLOAT,
PXERNH1O FLOAT,
PXERNHRO FLOAT,
PXERN FLOAT,
PXERNLAB FLOAT,
PXERNCOV FLOAT,
PRERELG FLOAT,
PRERNWA FLOAT,
PRERNHLY FLOAT,
PRWERNAL FLOAT,
PRHERNAL FLOAT,
PESCHLVL FLOAT,
PESCHENR FLOAT,
PESCHFT FLOAT,
PXSCHLVL FLOAT,
PXSCHENR FLOAT,
PXSCHFT FLOAT,
PRNLFSCH FLOAT,
PEDISEAR FLOAT,
PEDISEYE FLOAT,
PEDISREM FLOAT,
PEDISPHY FLOAT,
PEDISDRS FLOAT,
PEDISOUT FLOAT,
PXDISEAR FLOAT,
PXDISEYE FLOAT,
PXDISREM FLOAT,
PXDISPHY FLOAT,
PXDISDRS FLOAT,
PXDISOUT FLOAT,
PRDISFLG FLOAT,
PECERT1 FLOAT,
PECERT2 FLOAT,
PECERT3 FLOAT,
PXCERT1 FLOAT,
PXCERT2 FLOAT,
PXCERT3 FLOAT,
PWSSWGT FLOAT,
PWLGWGT FLOAT,
PWVETWGT FLOAT,
PWORWGT FLOAT,
PWFMWGT FLOAT,
PWCMPWGT FLOAT,
PTHR SMALLINT,
PTWK SMALLINT,
PTOT SMALLINT,
PTNMEMP1 FLOAT,
PTNMEMP2 FLOAT,
HRHHID BIGINT,
GTCBSA INT,
GTCO SMALLINT,
GTCBSAST SMALLINT,
GTCBSASZ SMALLINT,
GTCSA SMALLINT,
GTMETSTA SMALLINT,
GTINDVPC SMALLINT,
PTERN2 FLOAT,
PTERNH1C FLOAT,
PTIO1OCD FLOAT,
PTIO2OCD FLOAT,
PTERNH2 FLOAT,
PTERNH1O FLOAT,
PTERN FLOAT,
PTERNWA FLOAT,
PTERNHLY FLOAT,
'''

# %%
columnsPair=columnsName.split(',')

# %%
print(columnsPair)
# Out:
# ['\nCPSDATE DATE', '\nID BIGINT', '\nHRHHID2 SMALLINT', '\nHUFINAL SMALLINT', '\nOCCURNUM SMALLINT', '\nHUINTTYP SMALLINT', '\nHURESPLI SMALLINT', '\nHUPRSCNT SMALLINT', '\nHUTYPEA SMALLINT', '\nHUTYPB SMALLINT', '\nHUTYPC SMALLINT', '\nHUBUS SMALLINT', '\nHUBUSL1 SMALLINT', '\nHUBUSL2 SMALLINT', '\nHUBUSL3 SMALLINT', '\nHUBUSL4 SMALLINT', '\nHRMIS SMALLINT', '\nHRMONTH SMALLINT', '\nHRYEAR4 SMALLINT', '\nHRLONGLK SMALLINT', '\nQSTNUM INT', '\nGEREG SMALLINT', '\nGESTFIPS SMALLINT', '\nGEDIV SMALLINT', '\nHEHOUSUT SMALLINT', '\nHXHOUSUT SMALLINT', '\nHEPHONEO SMALLINT', '\nHXPHONEO SMALLINT', '\nHETELAVL SMALLINT', '\nHXTELAVL SMALLINT', '\nHETELHHD SMALLINT', '\nHXTELHHD SMALLINT', '\nHRHTYPE SMALLINT', '\nHRINTSTA SMALLINT', '\nHRNUMHOU SMALLINT', '\nHEFAMINC SMALLINT', '\nHXFAMINC SMALLINT', '\nHWHHWGT FLOAT', '\nHWHHWTLN FLOAT', '\nPULINENO FLOAT', '\nPUCHINHH FLOAT', '\nPUWK FLOAT', '\nPUBUS1 FLOAT', '\nPUDIS FLOAT', '\nPULAY FLOAT', '\nPUHROFF1 FLOAT', '\nPUHROFF2 FLOAT', '\nPU
# ...

# %%
pairs=[]
for pair in columnsPair:
  pair_=pair.split()
  if pair_:
    pairs.append(pair_)
print(pairs)
# Out:
# [['CPSDATE', 'DATE'], ['ID', 'BIGINT'], ['HRHHID2', 'SMALLINT'], ['HUFINAL', 'SMALLINT'], ['OCCURNUM', 'SMALLINT'], ['HUINTTYP', 'SMALLINT'], ['HURESPLI', 'SMALLINT'], ['HUPRSCNT', 'SMALLINT'], ['HUTYPEA', 'SMALLINT'], ['HUTYPB', 'SMALLINT'], ['HUTYPC', 'SMALLINT'], ['HUBUS', 'SMALLINT'], ['HUBUSL1', 'SMALLINT'], ['HUBUSL2', 'SMALLINT'], ['HUBUSL3', 'SMALLINT'], ['HUBUSL4', 'SMALLINT'], ['HRMIS', 'SMALLINT'], ['HRMONTH', 'SMALLINT'], ['HRYEAR4', 'SMALLINT'], ['HRLONGLK', 'SMALLINT'], ['QSTNUM', 'INT'], ['GEREG', 'SMALLINT'], ['GESTFIPS', 'SMALLINT'], ['GEDIV', 'SMALLINT'], ['HEHOUSUT', 'SMALLINT'], ['HXHOUSUT', 'SMALLINT'], ['HEPHONEO', 'SMALLINT'], ['HXPHONEO', 'SMALLINT'], ['HETELAVL', 'SMALLINT'], ['HXTELAVL', 'SMALLINT'], ['HETELHHD', 'SMALLINT'], ['HXTELHHD', 'SMALLINT'], ['HRHTYPE', 'SMALLINT'], ['HRINTSTA', 'SMALLINT'], ['HRNUMHOU', 'SMALLINT'], ['HEFAMINC', 'SMALLINT'], ['HXFAMINC', 'SMALLINT'], ['HWHHWGT', 'FLOAT'], ['HWHHWTLN', 'FLOAT'], ['PULINENO', 'FLOAT'], ['PUCHINHH', 
# ...

# %%
#table for V1
df_2021V1=['CPSDATE','ID','PEMLR', 'PESEX', 'PRDTOCC1', 'PRPERTYP', 'PRTAGE','PTDTRACE', 'PWCMPWGT']
var_names=['CPSDATE','ID','PEMLR', 'PESEX', 'PRDTOCC1', 'PRPERTYP', 'PRTAGE','PTDTRACE', 'PWCMPWGT']
print(df_2021V1==var_names)
print('\n')
for var in var_names:
  for pair in pairs:
    if var == pair[0]:
      print(f'{pair[0]} {pair[1]},')
# Out:
# True
#
#
# CPSDATE DATE,
# ID BIGINT,
# PEMLR FLOAT,
# PESEX FLOAT,
# PRDTOCC1 FLOAT,
# PRPERTYP FLOAT,
# PRTAGE FLOAT,
# PTDTRACE FLOAT,
# PWCMPWGT FLOAT,

# %%
#table for V2
df_2021V2=['CPSDATE','ID', 'PRTAGE', 'PWCMPWGT', 'PEHRUSL1', 'PEHRUSL2','PEHRACT1', 'PEHRACT2', 'PEERNHRO', 'PTERNWA']
var_names=['CPSDATE','ID','PRTAGE', 'PWCMPWGT', 'PEHRUSL1', 'PEHRUSL2', 'PEHRACT1', 'PEHRACT2', 'PEERNHRO', 'PTERNWA']
print(df_2021V2==var_names)
print('\n')
for var in var_names:
  for pair in pairs:
    if var == pair[0]:
      print(f'{pair[0]} {pair[1]},')
# Out:
# True
#
#
# CPSDATE DATE,
# ID BIGINT,
# PRTAGE FLOAT,
# PWCMPWGT FLOAT,
# PEHRUSL1 FLOAT,
# PEHRUSL2 FLOAT,
# PEHRACT1 FLOAT,
# PEHRACT2 FLOAT,
# PEERNHRO FLOAT,
# PTERNWA FLOAT,

# %%
#table for V3
df_2021V3=['CPSDATE', 'ID', 'PRTAGE', 'PWCMPWGT', 'PWORWGT', 'PEEDUCA', 'PRNMCHLD','PEMARITL', 'PRDTIND1', 'PRMJIND1']
var_names=['CPSDATE','ID', 'PRTAGE', 'PWCMPWGT', 'PWORWGT', 'PEEDUCA', 'PRNMCHLD', 'PEMARITL', 'PRDTIND1', 'PRMJIND1']
print(df_2021V3==var_names)
print('\n')
for var in var_names:
  for pair in pairs:
    if var == pair[0]:
      print(f'{pair[0]} {pair[1]},')
# Out:
# True
#
#
# CPSDATE DATE,
# ID BIGINT,
# PRTAGE FLOAT,
# PWCMPWGT FLOAT,
# PWORWGT FLOAT,
# PEEDUCA FLOAT,
# PRNMCHLD FLOAT,
# PEMARITL FLOAT,
# PRDTIND1 FLOAT,
# PRMJIND1 FLOAT,

# %%
#table for V4
df_2021V4=['CPSDATE', 'ID', 'PWCMPWGT', 'PRDTCOW1', 'HRMIS', 'PEIO1COW', 'PEMJOT','PEHRFTPT', 'HRINTSTA']
var_names=['CPSDATE', 'ID', 'PWCMPWGT', 'PRDTCOW1', 'HRMIS', 'PEIO1COW', 'PEMJOT','PEHRFTPT', 'HRINTSTA']
print(df_2021V4==var_names)
print('\n')
for var in var_names:
  for pair in pairs:
    if var == pair[0]:
      print(f'{pair[0]} {pair[1]},')
# Out:
# True
#
#
# CPSDATE DATE,
# ID BIGINT,
# PWCMPWGT FLOAT,
# PRDTCOW1 FLOAT,
# HRMIS SMALLINT,
# PEIO1COW FLOAT,
# PEMJOT FLOAT,
# PEHRFTPT FLOAT,
# HRINTSTA SMALLINT,

# %% [markdown]
# create table cps20032021dat_V1(
# CPSDATE DATE,
# ID BIGINT,
# PEMLR FLOAT,
# PESEX FLOAT,
# PRDTOCC1 FLOAT,
# PRPERTYP FLOAT,
# PRTAGE FLOAT,
# PTDTRACE FLOAT,
# PWCMPWGT FLOAT,
# )
#
# create table cps20032021dat_V2(
# CPSDATE DATE,
# ID BIGINT,
# PRTAGE FLOAT,
# PWCMPWGT FLOAT,
# PEHRUSL1 FLOAT,
# PEHRUSL2 FLOAT,
# PEHRACT1 FLOAT,
# PEHRACT2 FLOAT,
# PEERNHRO FLOAT,
# PTERNWA FLOAT,
# )
#
# create table cps20032021dat_V3(
# CPSDATE DATE,
# ID BIGINT,
# PRTAGE FLOAT,
# PWCMPWGT FLOAT,
# PWORWGT FLOAT,
# PEEDUCA FLOAT,
# PRNMCHLD FLOAT,
# PEMARITL FLOAT,
# PRDTIND1 FLOAT,
# PRMJIND1 FLOAT,
# )
#
# create table cps20032021dat_V4(
# CPSDATE DATE,
# ID BIGINT,
# PWCMPWGT FLOAT,
# PRDTCOW1 FLOAT,
# HRMIS SMALLINT,
# PEIO1COW FLOAT,
# PEMJOT FLOAT,
# PEHRFTPT FLOAT,
# HRINTSTA SMALLINT,
# )

# %%
df_2021V1=['CPSDATE','ID','PEMLR', 'PESEX', 'PRDTOCC1', 'PRPERTYP', 'PRTAGE','PTDTRACE', 'PWCMPWGT']
df_2021V2=['CPSDATE','ID', 'PRTAGE', 'PWCMPWGT', 'PEHRUSL1', 'PEHRUSL2','PEHRACT1', 'PEHRACT2', 'PEERNHRO', 'PTERNWA']
df_2021V3=['CPSDATE', 'ID', 'PRTAGE', 'PWCMPWGT', 'PWORWGT', 'PEEDUCA', 'PRNMCHLD','PEMARITL', 'PRDTIND1', 'PRMJIND1']
df_2021V4=['CPSDATE', 'ID', 'PWCMPWGT', 'PRDTCOW1', 'HRMIS', 'PEIO1COW', 'PEMJOT','PEHRFTPT', 'HRINTSTA']
_df_col=df_2021V1+df_2021V2+df_2021V3+df_2021V4
df_col=set(_df_col)
df_col=list(df_col)
df_col.sort()


print(df_col)
len(df_col)
# Out:
# ['CPSDATE', 'HRINTSTA', 'HRMIS', 'ID', 'PEEDUCA', 'PEERNHRO', 'PEHRACT1', 'PEHRACT2', 'PEHRFTPT', 'PEHRUSL1', 'PEHRUSL2', 'PEIO1COW', 'PEMARITL', 'PEMJOT', 'PEMLR', 'PESEX', 'PRDTCOW1', 'PRDTIND1', 'PRDTOCC1', 'PRMJIND1', 'PRNMCHLD', 'PRPERTYP', 'PRTAGE', 'PTDTRACE', 'PTERNWA', 'PWCMPWGT', 'PWORWGT']
# 27
